# %% [markdown]
# ### 01-01 What is ML?

# %% [markdown]
# Features + Target -> ML -> Model
#
# Then, Features + Model -> Predictions

# %% [markdown]
# ### 01-02 ML vs. Rules

# %% [markdown]
# Converting to numbers
#
# Predictions as probability

# %% [markdown]
# ### 01-03 Supervised ML

# %% [markdown]
# Supervised ML:
# g(X) ≈ y
#
# Regression, Binary Classification, Multiclass Classification, Ranking

# %% [markdown]
# ### 01-04 CRISP-DM

# %% [markdown]
# ![CRISP-DM](crisp-dm.png)

# %% [markdown]
# ### 01-05 Model Selection

# %% [markdown]
# 60% Training <br>
# 20% Validation <br>
#
# -- Select best model --<br>
# -- Train on both train and val --
#
# 20% Testing <br><br>
#
#
# Process:
# 1. Split
# 2. Train
# 3. Val
# 4. Select the best
# 5. Test
# 6. Check

# %% [markdown]
# ### 01-07 Numpy
